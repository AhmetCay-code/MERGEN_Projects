# %%
from selenium import webdriver
import chromedriver_binary
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
import random
import time
import pandas as pd

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# C:\Users\ahmet\AppData\Local\Temp\ipykernel_19020\1503906442.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get('https://www.interwetten.de/en/account/logon?returnUrl=%2fen%2fsportsbook')

# %%
user_name = driver.find_element('xpath','//*[@id="UserName"]')

# %%
user_name.send_keys('Kesoglu')

# %%
password = driver.find_element('xpath','//*[@id="Password"]')

# %%
password.send_keys('Kesoglu474')

# %%
login = driver.find_element('xpath','//*[@id="lnkLogin"]')

# %%
login.click()

# %%
driver.get('https://www.interwetten.de/en/sport/leaguelist?leagueIds=1029,1021,1019,1030,1024&offergroupid=8')

# %%
teams = driver.find_elements('xpath',"//*[@class='info']")

# %%
odds = driver.find_elements('xpath',"//*[@class='b n2']")

# %%
odds_list = []
for o in range(len(odds)):
    odds_list.append(odds[o].text)

# %%
teams_list = []
for t in range(len(teams)):
    teams_list.append(teams[t].text)

# %%
odd_list_over=[]
odd_list_under=[]
for i in range(len(odds_list)):
    if odds_list[i][:8]=='Over 2.5':
        odd_list_over.append(odds_list[i][9:13])
        odd_list_under.append(odds_list[i][24:28])

# %%
df=pd.DataFrame(zip(teams_list,odd_list_over,odd_list_under), columns=['match','over','under'])
new = df["match"].str.split("-", n = 1, expand = True)
df['Home']=new[0]
df['Away']=new[1]
df=df.drop('match',axis=1)

# %%
df
# Out:
#     over under                       Home                 Away
# 0   2.35  1.55                AC Ajaccio            Angers SCO
# 1   1.83  1.90              ESTAC Troyes             FC Nantes
# 2   1.75  2.00                AJ Auxerre             AS Monaco
# 3   1.75  2.00          Clermont Foot 63             Lille OSC
# 4   1.33  3.15                  Paris SG         RC Strasbourg
# 5   1.77  2.00            Stade Brest 29        Olympique Lyon
# 6   1.75  2.05                FC Lorient           Montpellier
# 7   1.77  2.00               Stade Reims          Stade Rennes
# 8   2.05  1.73                  OGC Nice                  Lens
# 9   1.63  2.20       Olympique Marseille           Toulouse FC
# 10  2.15  1.67                 Girona FC        Rayo Vallecano
# 11  2.05  1.73       Real Betis Balompie       Athletic Bilbao
# 12  1.70  2.10           Atletico Madrid              Elche CF
# 13  2.85  1.40                    Getafe              Mallorca
# 14  2.20  1.63             Celta de Vigo            FC Sevilla
# 15  2.20  1.63                  Cadiz CF            UD Almeria
# 16  1.57  2.35                Valladolid           Real Madrid
# 17  1.43  2.75              FC Barcelona    Espanyol Barcelona
# 18  2.15  1.65             Real Sociedad               Osasuna
# 19  1.95  1.83                Villarreal              Valencia
# 20  1.40  2.90                RB Leipzig         Bayern Munich
# 21  1.90  1.85              Union Berlin            Hoffenheim
# 22  1.55  2.40       Eintracht Frankfurt            Schalke 04
# 23  1.83  1.95             VfL Wolfsburg           SC Freiburg
# 24  1.73  2.05                VfL Bochum            Hertha BSC
# 25  1.75  2.00             VfB Stuttgart              Mainz 05
# 26  1.63  2.25             1. FC Cologne         Werder Bremen
# 27  1.43  2.75                  Dortmund           FC Augsburg
# 28  1.55  2.40  Borussia Monchengladbach            Leverkusen
# 29  1.77  2.00              Brentford FC             Tottenham
# 30  1.85  1.90            Crystal Palace                Fulham
# 31  2.10  1.70                   Everton         Wolverhampton
# 32  1.75  2.00                 Leicester             Newcastle
# 33  1.85  1.90               Southampton              Brighton
# 34  1.57  2.35               Aston Villa             Liverpool
# 35  1.73  2.05                   Arsenal              West Ham
# 36  1.63  2.25                Chelsea FC           Bournemouth
# 37  1.60  2.25         Manchester United     Nottingham Forest
# 38  1.40  2.85              Leeds United       Manchester City
# 39  1.67  2.15               Salernitana              AC Milan
# 40  1.90  1.90                  Sassuolo             Sampdoria
# 41  1.70  2.10                    Spezia              Atalanta
# 42  1.90  1.85                 FC Torino         Hellas Verona
# 43  2.15  1.65                     Lecce            Lazio Rome
# 44  1.95  1.83                   AS Roma               Bologna
# 45  1.90  1.90              US Cremonese        Juventus Turin
# 46  1.85  1.90                Fiorentina              AC Monza
# 47  1.63  2.20              Inter Milano            SSC Napoli
# 48  1.63  2.25                   Udinese             Empoli FC

# %% [markdown]
# * df modele gidicek
# * gelecek olan 3 sonuc secilecek

# %%
select_odd1 = driver.find_element('xpath','//*[@id="TBL_Content_1024"]/tbody/tr[3]/td[2]/table/tbody/tr[1]/td[1]')

# %%
select_odd1.click()

# %%
select_odd2 = driver.find_element('xpath','//*[@id="TBL_Content_1024"]/tbody/tr[4]/td[2]/table/tbody/tr[1]/td[1]')

# %%
select_odd2.click()

# %%
bet_amount = driver.find_element('xpath','//*[@id="amount_combi"]')

# %%
bet_amount.send_keys('5')

# %%
submit=driver.find_element('xpath','//*[@id="BS_Button_Submit"]')

# %%
submit.click()
