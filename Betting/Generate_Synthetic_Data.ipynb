# %%
! pip install -U ydata-profiling
# Out:
# ...
#      ------------------------------------- 345.9/345.9 KB 10.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 663.5/663.5 KB 43.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 102.7/102.7 KB ? eta 0:00:00
# ...
#      ---------------------------------------- 296.5/296.5 KB ? eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 2.2/2.2 MB 46.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.7/4.7 MB 50.2 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27104 sha256=e8b259ba8d8f9cc398f30531448eda468883b282de13d4231d5495d94357a1ef
#   Stored in directory: c:\users\ahmet\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# ...
#   Attempting uninstall: typing-extensions
# ...

# %%
import pandas as pd

from ydata_profiling import ProfileReport

# ayni adamlarin sentetik data olayina bak

# %%
x1=pd.read_csv('Data_Eng_Phase/DFFs/bundesliga_dff.csv')
x2=pd.read_csv('Data_Eng_Phase/DFFs/laliga_dff.csv')
x3=pd.read_csv('Data_Eng_Phase/DFFs/seria_dff.csv')
frames=[x1,x2,x3]
dff=pd.concat(frames)

dff=dff.dropna()
dff=dff.reset_index(drop=True)
#dff.label=dff.label.astype('category')

# %%
dff
# Out:
#        AvgH  AvgD   AvgA  Avg>2.5  Avg<2.5  label  week  booking_points_home  \
# 0      2.40  3.38   2.87     1.85     1.93      0     4            36.666667
# 1      2.80  3.35   2.43     1.73     2.05      1     4            26.666667
# 2      1.86  3.54   4.07     1.69     2.10      1     4            33.333333
# 3      2.29  3.38   3.00     1.68     2.12      1     4            23.333333
# 4      6.34  4.17   1.50     1.58     2.27      1     4            33.333333
# ...     ...   ...    ...      ...      ...    ...   ...                  ...
# 10749  5.75  4.64   1.53     1.46     2.69      1    38            23.333333
# 10750  1.13  9.10  20.49     1.27     3.73      1    38            13.333333
# 10751  6.63  4.87   1.46     1.45     2.76      1    38            20.000000
# 10752  1.70  4.17   4.60     1.61     2.34      1    38            38.333333
# 10753  4.68  4.05   1.72     1.73     2.12      0    38            63.333333
#
# ...
